# %%
import pandas as pd
df = pd.read_csv('C:/Users/Akansh/Desktop/churn-project/cleaned_churn.CSV')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Overall churn rate
print(df['Churn'].mean() * 100, '% customers churned')
# Out:
# 26.449223757299528 % customers churned

# %%
# Contract type ke hisaab se churn rate
df.groupby('Contract')['Churn'].mean()*100
# Out:
# Contract
# Month-to-month    42.642097
# One year          11.269518
# Two year           2.831858
# Name: Churn, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Tenure vs churn — naye customers zyada churn karte hain?
sns.boxplot(x='Churn', y='tenure', data=df)
plt.show()

# %%
# Monthly charges vs churn
sns.boxplot(x='Churn' , y='MonthlyCharges' , data = df)
# Out:
# <Axes: xlabel='Churn', ylabel='MonthlyCharges'>

# %%
print(df['Churn'].mean())
# Out:
# 0.2644922375729953
